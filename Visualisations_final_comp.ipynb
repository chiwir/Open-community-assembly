# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Import data check directory
df_1 = pd.read_excel('Supplementry_Appendix_S3.xlsx')
#df_2 = pd.read_excel('Chapter1_spreadsheet.xlsx')
#df_3 = pd.read_excel('dynamics_sample_data.xlsx')
df_1
# Out:
#        sigmar    sigma     lamda      Shan      Simp     Abund2        Stab1  \
# 0    0.536935  0.29414  0.742032  3.098073  0.076658   3.877413    48.466317
# 1    0.536935  0.29414  2.484732  3.331790  0.062035   7.152953  1061.239434
# 2    0.536935  0.29414  0.341722  2.953433  0.082468   2.965940    22.762864
# 3    0.536935  0.29414  0.305252  2.900786  0.086412   2.871603    22.000395
# 4    0.536935  0.29414  3.365534  3.384642  0.057540   8.498170  5109.224373
# ..        ...      ...       ...       ...       ...        ...          ...
# 995  0.577255  0.15826  1.566830  3.770389  0.040714   7.937715   400.974118
# 996  0.577255  0.15826  1.533918  3.785445  0.040253   7.796550   333.153051
# 997  0.577255  0.15826  3.362893  3.893084  0.036199  11.195464  7994.267962
# 998  0.577255  0.15826  0.498928  3.568036  0.044850   5.297451    52.013940
# 999  0.577255  0.15826  0.418521  3.547583  0.044578   5.018659    38.543570
#
#         Stab1_var      Stone      Stab2  ...  DeltaRAO1  DeltaRAO5  \
# 0    9.939821e+03  28.953484  14.476742  ...  -0.747800  -1.166457
# 1    1.447838e+07  34.449765  17.224882  ...  -0.457770  -0.521669
# 2    5.418102e+02  25.883885  12.941942  ...  -3.191164  -4.207172
# 3    4.332291e+02  26.552176  13.276088  ...   0.289207   1.807446
# 4    1.790024e+09  36.700269  18.350134  ...  -0.234652  -0.011468
# ..            ...        ...        ...  ...        ...        ...
# 995  2.040769e+06  57.193915  28.596957  ...  -0.933899  -0.935172
# 996  1.376287e+06  54.541297  27.270648  ...   2.708698   2.036321
# 997  2.105327e+09  66.172760  33.086380  ...   0.412175   0.546604
# 998  6.158758e+03  45.835100  22.917550  ...   0.140977  -0.831432
# 999  2.687364e+03  39.802493  19.901246  ...  -3.554856  -4.900599
#
#      DeltaRAO10  DeltaRAO50  DeltaRAO100  DeltaRAO200   RAO_mean    RAO_var  \
# 0     -0.912568   -2.669814     0.592728     2.383541  16.368816  28.341683
# 1      0.343573    1.665579    -1.864448    -0.163580  24.784827  38.296352
# 2     -4.885593   -4.666000    -6.416255    -4.515292  12.722934  27.038391
# 3      3.380511    2.417247     4.055482     3.785110  12.402118  27.562832
# 4     -1.194380   -0.751221     0.846517     3.353290  26.107571  34.510754
# ..          ...         ...          ...          ...        ...        ...
# 995   -1.577229   -3.058346    -1.367076    -1.452700  18.262653  22.344047
# 996    1.013273    2.479329     2.613240    -0.305148  18.919678  23.438677
# 997    0.946859    0.655930    -0.289062    -0.796587  23.751102  23.528879
# 998   -3.048218   -2.063213    -3.055290    -3.463033  11.164641  18.331138
# 999   -5.087092   -6.219423    -4.750223    -3.064596  10.561402  15.833564
#
#        Eigen_mean     Eigen_var
# 0    7.667861e-16  6.784435e-32
# 1    6.226253e-16  3.209880e-32
# 2    5.975987e-16  3.713702e-32
# 3   -6.068123e-09  2.396321e-16
# 4    6.215762e-16  3.960669e-32
# ..            ...           ...
# 995 -4.382202e-04  6.004306e-07
# 996 -1.450890e-08  1.203356e-15
# 997 -4.253612e-05  1.885395e-09
# 998 -4.386778e-06  1.966690e-10
# 999 -5.443851e-05  3.104336e-08
#
# [1000 rows x 47 columns]

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 47 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sigmar          1000 non-null   float64
#  1   sigma           1000 non-null   float64
#  2   lamda           1000 non-null   float64
#  3   Shan            1000 non-null   float64
#  4   Simp            1000 non-null   float64
#  5   Abund2          1000 non-null   float64
#  6   Stab1           1000 non-null   float64
#  7   Stab1_var       1000 non-null   float64
#  8   Stone           1000 non-null   float64
#  9   Stab2           1000 non-null   float64
#  10  Stab2_var       1000 non-null   float64
#  11  Stab3           1000 non-null   float64
#  12  Stab3_var       1000 non-null   float64
#  13  Stab4           1000 non-null   float64
#  14  Stab4_var       1000 non-null   float64
#  15  Stab5           1000 non-null   float64
#  16  Stab5_var       1000 non-null   float64
#  17  Stab6           1000 non-null   float64
#  18  Stab7           1000 non-null   float64
#  19  New_formula     1000 non-null   float64
#  20  New_formula1    1000 non-null   float64
#  21  Current_sp      1000 non-null   float64
#  22  Current_sp_var  1000 non-null   float64
#  23  Trait_var       1000 non-null   float64
#  24  trait_mean      1000 non-null   float64
#  25  Aij             1000 non-null   float64
#  26  Aij_var         1000 non-null   float64
#  27  Ri              1000 non-null   float64
#  28  Ri_var          1000 non-null   float64
#  29  Introd          1000 non-null   float64
#  30  Introd_var      1000 non-null   float64
#  31  Jaccard_lag1    1000 non-null   float64
#  32  Jaccard_lag5    1000 non-null   float64
#  33  Jaccard_lag10   1000 non-null   float64
#  34  Jaccard_lag50   1000 non-null   float64
#  35  Jaccard_lag100  1000 non-null   float64
#  36  Jaccard_lag200  1000 non-null   float64
#  37  DeltaRAO1       1000 non-null   float64
#  38  DeltaRAO5       1000 non-null   float64
#  39  DeltaRAO10      1000 non-null   float64
#  40  DeltaRAO50      1000 non-null   float64
#  41  DeltaRAO100     1000 non-null   float64
#  42  DeltaRAO200     1000 non-null   float64
#  43  RAO_mean        1000 non-null   float64
#  44  RAO_var         1000 non-null   float64
#  45  Eigen_mean      1000 non-null   float64
#  46  Eigen_var       1000 non-null   float64
# dtypes: float64(47)
# memory usage: 367.3 KB

# %%
df_1.columns
# Out:
# Index(['sigmar', 'sigma', 'lamda', 'Shan', 'Simp', 'Abund2', 'Stab1',
#        'Stab1_var', 'Stone', 'Stab2', 'Stab2_var', 'Stab3', 'Stab3_var',
#        'Stab4', 'Stab4_var', 'Stab5', 'Stab5_var', 'Stab6', 'Stab7',
#        'New_formula', 'New_formula1', 'Current_sp', 'j_form', 'Current_sp_var',
#        'Trait_var', 'trait_mean', 'Aij', 'Aij_var', 'Ri', 'Ri_var', 'Introd',
#        'Introd_var', 'Jaccard_lag1', 'Jaccard_lag5', 'Jaccard_lag10',
#        'Jaccard_lag50', 'Jaccard_lag100', 'Jaccard_lag200', 'DeltaRAO1',
#        'DeltaRAO5', 'DeltaRAO10', 'DeltaRAO50', 'DeltaRAO100', 'DeltaRAO200',
#        'RAO_mean', 'RAO_var', 'Eigen_mean', 'Eigen_var'],
#       dtype='object')

# %%
# Adjust the figure size
plt.figure(figsize=(16, 8))
# Plotting the trait distribution
plt.bar(df_1['trait_mean'], df_1['Abund2'], color='blue')
plt.xlabel('Trait Values', fontsize=20)
plt.ylabel('Population Size', fontsize=20)
# Increase the font size of legend
#plt.legend(fontsize=16)

# Increase the font size of axis ticks
plt.yticks(fontsize=18)
plt.xticks(fontsize=18)
# Show the plot
plt.show()

# %%
from matplotlib import cm
plt.figure(figsize=(10, 8))
norm = plt.Normalize(df_1['Current_sp'].min(), df_1['Current_sp'].max())
cmap = cm.viridis  # Choose a colormap, e.g., viridis

# Create a scatter plot
scatter = plt.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag1'], s=df_1['Current_sp'], c=df_1['Current_sp'], cmap=cmap, norm=norm, alpha=0.9)

# Add labels and title
plt.xlabel(r' Openness, Re($\lambda$)')
plt.ylabel(r'Jaccard Similarity, $T$')
#plt.title('Scatter Plot with Size-Based Colors')

# Create a colorbar
cbar = plt.colorbar(scatter, label='Species richness')

# Show the plot
plt.show()

# %% [markdown]
# ## Main Text Figures

# %%
df_1['Prod_I_R'] = df_1['Introd'] * df_1['Ri']

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(20, 8), sharex=True, sharey='none')

# Normalize the size values to map to a colormap
norm = plt.Normalize(df_1['Current_sp'].min(), df_1['Current_sp'].max())
cmap = cm.viridis  # Choose a colormap, e.g., viridis

# Plotting the column means for the first subplot
scatter = axs[0].scatter(df_1['Eigen_mean'], df_1["Jaccard_lag1"], s=df_1['Current_sp'], c=df_1['Current_sp'], cmap=cmap, norm=norm, alpha=0.9)
axs[0].set_ylabel(r"Jaccard Similarity, $T$", fontsize=20)
axs[0].set_xlabel(r"Openness, Re($\lambda$)", fontsize=20)
axs[0].tick_params(axis='both', labelsize=18)
axs[0].xaxis.set_tick_params(which='both', width=1)
axs[0].yaxis.set_tick_params(which='both', width=1)
axs[0].set_title("a", fontsize=20, loc="left", fontweight='bold')

# Plotting the transition rate for the second subplot
scatter2 = axs[1].scatter(df_1['Eigen_mean'], df_1['Prod_I_R'], s=df_1['Current_sp'], c=df_1['Current_sp'], cmap=cmap, norm=norm, alpha=0.9)
axs[1].set_ylabel(r"Transition rate, $\hat{r}\rho$", fontsize=20)
axs[1].set_xlabel(r"Openness, Re($\lambda$)", fontsize=20)
axs[1].tick_params(axis='both', labelsize=18)
axs[1].xaxis.set_tick_params(which='both', width=1)
axs[1].yaxis.set_tick_params(which='both', width=1)
axs[1].set_title("b", fontsize=20, loc="left", fontweight='bold')

# Create a single colorbar for both subplots
cbar = fig.colorbar(scatter, ax=axs, label='Species richness')
cbar.ax.tick_params(labelsize=18)

plt.show()

# %%
from matplotlib import cm
from matplotlib.colors import Normalize
import matplotlib.pyplot as plt

# Assuming df_2['Current_sp'] contains the values for the colorbar
norm = Normalize(df_1['Current_sp'].min(), df_1['Current_sp'].max())
cmap = cm.viridis

# Create the figure with adjusted figsize
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(20, 8), sharex=True, sharey='none')

# Plotting the first subplot
scatter1 = axs[0].scatter(df_1['Eigen_mean'], df_1["Jaccard_lag1"], s=df_1['Current_sp'], c=df_1['Current_sp'], cmap=cmap, norm=norm, alpha=0.9)
axs[0].set_ylabel(r"Jaccard Similarity, $T$", fontsize=20)
axs[0].set_xlabel(r"Openness, Re($\lambda$)", fontsize=20)
axs[0].tick_params(axis='both', labelsize=18)
axs[0].xaxis.set_tick_params(which='both', width=1)
axs[0].yaxis.set_tick_params(which='both', width=1)
axs[0].set_title("a", fontsize=20, loc="left", fontweight='bold')

# Plotting the second subplot
scatter2 = axs[1].scatter(df_1['Eigen_mean'], df_1['Prod_I_R'], s=df_1['Current_sp'], c=df_1['Current_sp'], cmap=cmap, norm=norm, alpha=0.9)
axs[1].set_ylabel(r" Transition rate, $\hat{r}\rho$", fontsize=20)
axs[1].set_xlabel(r"Openness, Re($\lambda$)", fontsize=20)
axs[1].tick_params(axis='both', labelsize=18)
axs[1].xaxis.set_tick_params(which='both', width=1)
axs[1].yaxis.set_tick_params(which='both', width=1)
axs[1].set_title("b", fontsize=20, loc="left", fontweight='bold')

# Create a ScalarMappable for mapping the color values to colors
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])  # empty array since the values will come from df_2['Current_sp']

# Create a colorbar
cbar = plt.colorbar(sm, ax=axs, label='Species richness')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

Stone= (1-df_1['Aij'])**2/df_1['Aij_var']
#df_1['New_formula1'] = (df_1['Ri']*(df_1['Introd']*Stone))**0.75

# Create the figure with adjusted figsize
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(12, 6), sharex=True, sharey='none')


# Define the data and labels
data = [
    (df_1['Current_sp'], Stone, 'a', r"$S_3$ "),
    
    (df_1['Current_sp'], df_1['New_formula1'], 'b', r"$\hat{S}=\sqrt{\hat{\lambda}\hat{R}\frac{(1-\mu_A)^2}{\sigma_A^2}}$"),
    
]

# Define the subplot labels
subplot_labels = ['a', 'b']

# Iterate over the subplots and data
for i, (ax, (x, y, title, equation)) in enumerate(zip(axs.flat, data)):
    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    line = slope * np.array(x) + intercept

    # Plot scatter plot
    ax.scatter(x, y,s=14, color='black',label='Data')

    # Plot regression line
    #ax.plot(x, line, color='red')
    # Add subplot label at the top left corner using 'top left' option
    ax.text(0, 1.1, subplot_labels[i], transform=ax.transAxes, fontsize=18, fontweight='bold', va='top', ha='left')
    # Add R-squared value as text
    r_squared = r_value**2
    #ax.annotate(f'$R^2$ = {r_squared:.2f}', xy=(0.6, 0.1), xycoords='axes fraction', fontsize=16)
    print(r_squared)

    # Add custom equation of the regression line
    #ax.text(0.2, 0.8, equation, transform=ax.transAxes, fontsize=20, color='black')

    if i%2==0:
        # Add labels and legend
        ax.set_ylabel('Predicted richness', fontsize=20, color='black')

    # Add subplot label
    #ax.text(0.05, 0.95, subplot_labels[i], transform=ax.transAxes, fontsize=18, fontweight='bold', va='top')

    # Increase the font size of the tick labels
    ax.tick_params(axis='both', labelsize=18)

    # Bolden the tick labels
    ax.xaxis.set_tick_params(which='both', width=1)
    ax.yaxis.set_tick_params(which='both', width=1)

    # Add x-axis label to bottom row subplots
    ax.set_xlabel('Observed richness', fontsize=20, color='black')

# Adjust spacing between subplots
plt.tight_layout()

# Save the plot as a PNG image
plt.savefig('rich_com.png', dpi=900)

# Show the plot
plt.show()
# Out:
# 7.890701017141722
# 0.6845450659831411
# 0.9837909768288883

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Assuming your dataframe is named 'df' and contains the columns of interest
columns_of_interest = ['Jaccard_lag1', 'Jaccard_lag5', 'Jaccard_lag10', 'Jaccard_lag50', 'Jaccard_lag100', 'Jaccard_lag200']

# Create the figure with adjusted figsize
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(16, 8), sharex=True, sharey='none')

# Box plots for Jaccard Similarity
axs[0].boxplot(df_1[columns_of_interest].values, labels=['1', '5', '10', '50', '100', '200'], showfliers=False)
axs[0].set_ylabel(r"Jaccard Similarity, $T$", fontsize=20)
axs[0].set_xlabel(r"Time lag, $\tau$", fontsize=20)
axs[0].tick_params(axis='both', labelsize=18)
axs[0].xaxis.set_tick_params(which='both', width=1)
axs[0].yaxis.set_tick_params(which='both', width=1)
#axs[0].text(0.5, 1.09, "a", fontsize=18, fontweight='bold', va='top', ha='left')
#axs[0].text(0, 1.1, 'a' ,rm=axs.transAxes, fontsize=18, fontweight='bold', va='top', ha='left')
# Assuming your dataframe is named 'df' and contains the columns of interest for Functional Turnover
columns_of_interest1 = ['DeltaRAO1', 'DeltaRAO5', 'DeltaRAO10', 'DeltaRAO50', 'DeltaRAO100', 'DeltaRAO200']

# Box plots for Functional Turnover
axs[1].boxplot(df_1[columns_of_interest1].values,labels=['1', '5', '10', '50', '100', '200'],showfliers=False)
axs[1].set_ylabel(r"Functional Turnover, $\Delta Q$", fontsize=20)
axs[1].set_xlabel(r"Time lag, $\tau$", fontsize=20)
axs[1].tick_params(axis='both', labelsize=18)
axs[1].xaxis.set_tick_params(which='both', width=1)
axs[1].yaxis.set_tick_params(which='both', width=1)
#axs[1].text(0.5, 10.95, "b", fontsize=18, fontweight='bold', va='top', ha='left')

axs[0].set_title("a", fontsize=20,loc="left",fontweight='bold')
axs[1].set_title("b", fontsize=20,loc="left",fontweight='bold')
# Set titles for subplots
#Set the overall title for the subplot
#plt.suptitle('Subplots of Boxplots for Two Datasets')
#axs[1].text(0, 1.1, 'b', transform=axs.transAxes, fontsize=18, fontweight='bold', va='top', ha='left')
# Adjust the spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\chiwi\AppData\Local\Temp\ipykernel_37304\2893790459.py:12: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axs[0].boxplot(df_1[columns_of_interest].values, labels=['1', '5', '10', '50', '100', '200'], showfliers=False)
# C:\Users\chiwi\AppData\Local\Temp\ipykernel_37304\2893790459.py:24: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axs[1].boxplot(df_1[columns_of_interest1].values,labels=['1', '5', '10', '50', '100', '200'],showfliers=False)

# %% [markdown]
# ## Supplementary figures

# %%
from matplotlib import cm
plt.figure(figsize=(16, 8))
norm = plt.Normalize(df_1['sigmar'].min(), df_1['sigmar'].max())
cmap = cm.viridis  # Choose a colormap, e.g., viridis

# Create a scatter plot
scatter = plt.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag1'], s=df_1['sigmar'], c=df_1['sigmar'], cmap=cmap, norm=norm, alpha=1)

# Add labels and title
plt.xlabel(r'Openness, Re($\lambda_m$)',fontsize=20)
plt.ylabel(r'Jaccard Similarity,$T$',fontsize=20)
#plt.title('Scatter Plot with Size-Based Colors')
# Increase the font size of axis ticks
plt.yticks(fontsize=18)
plt.xticks(fontsize=18)
# Create a colorbar
cbar = plt.colorbar(scatter, label=r'$\sigma_r$')
cbar.ax.yaxis.label.set_fontsize(18)
cbar.ax.tick_params(axis='x', labelsize=20)

plt.savefig("FigS11.png")   # PNG file
# plt.savefig("graph.jpg") # JPG file
# Show the plot
plt.show()

# %%
from matplotlib import cm
plt.figure(figsize=(16, 8))
norm = plt.Normalize(df_1['sigma'].min(), df_1['sigma'].max())
cmap = cm.viridis  # Choose a colormap, e.g., viridis

# Create a scatter plot
scatter = plt.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag1'], s=df_1['sigma'], c=df_1['sigma'], cmap=cmap, norm=norm, alpha=1)

# Add labels and title
plt.xlabel(r'Openness, Re($\lambda_m$)',fontsize=20)
plt.ylabel(r'Jaccard Similarity, $T$',fontsize=20)
#plt.title('Scatter Plot with Size-Based Colors')
# Increase the font size of axis ticks
plt.yticks(fontsize=18)
plt.xticks(fontsize=18)

# Create a colorbar
cbar = plt.colorbar(scatter, label=r'$\sigma_\alpha$')
cbar.ax.yaxis.label.set_fontsize(18)
cbar.ax.tick_params(axis='x', labelsize=20) 

plt.savefig("FigS12.png")   # PNG file
# plt.savefig("graph.jpg") # JPG file
# Show the plot
plt.show()

# %%
from matplotlib import cm
plt.figure(figsize=(16, 8))
norm = plt.Normalize(df_1['Introd'].min(), df_1['Introd'].max())
cmap = cm.viridis  # Choose a colormap, e.g., viridis

# Create a scatter plot
scatter = plt.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag1'], s=df_1['Introd'], c=df_1['Introd'], cmap=cmap, norm=norm, alpha=1)

# Add labels and title
plt.xlabel(r'Openness, Re($\lambda_m$)', fontsize=20)
plt.ylabel(r'Jaccard Similarity, $T$',fontsize=20)
#plt.title('Scatter Plot with Size-Based Colors')

# Create a colorbar
cbar = plt.colorbar(scatter, label=r'$\rho$')
cbar.ax.yaxis.label.set_fontsize(18)
cbar.ax.tick_params(axis='x', labelsize=20) 

plt.savefig("FigS10.png")   # PNG file
# plt.savefig("graph.jpg") # JPG file
# Show the plot
plt.show()

# %%
df_1['Ratio'] = df_1['sigma']/df_1['sigmar']

# %%
from matplotlib import cm
plt.figure(figsize=(16, 8))
norm = plt.Normalize(df_1['Ratio'].min(), df_1['Ratio'].max())
cmap = cm.viridis  # Choose a colormap, e.g., viridis

# Create a scatter plot
scatter = plt.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag1'], s=df_1['Ratio'], c=df_1['Ratio'], cmap=cmap, norm=norm, alpha=1)

# Add labels and title
plt.xlabel(r' Openness, Re($\lambda_m$)',fontsize=20)
plt.ylabel(r'Jaccard Similarity, $T$',fontsize=20)
#plt.title('Scatter Plot with Size-Based Colors')
# Increase the font size of axis ticks
plt.yticks(fontsize=18)
plt.xticks(fontsize=18)

# Create a colorbar
cbar = plt.colorbar(scatter, label=r'$\sigma_\alpha/\sigma_r$')
cbar.ax.yaxis.label.set_fontsize(18)
cbar.ax.tick_params(axis='x', labelsize=20)

plt.savefig("FigS13.png")   # PNG file
# plt.savefig("graph.jpg") # JPG file
# Show the plot
plt.show()

# %%
from matplotlib import cm
import matplotlib.pyplot as plt

# Create a figure with two subplots
fig, axes = plt.subplots(2, 1, figsize=(16, 16))

# First subplot
ax1 = axes[0]
norm1 = plt.Normalize(df_1['Current_sp'].min(), df_1['Current_sp'].max())
cmap1 = cm.viridis

# Scatter plot for Jaccard Lag1
scatter1 = ax1.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag1'], s=df_1['Current_sp'], c=df_1['Current_sp'], cmap=cmap1, norm=norm1, alpha=0.7, marker='o', label='Jaccard Lag1')

# Scatter plot for Jaccard Lag5
scatter2 = ax1.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag5'], s=df_1['Current_sp'], c=df_1['Current_sp'], cmap=cmap1, norm=norm1, alpha=0.7, marker='s', label='Jaccard Lag5')

# Scatter plot for Jaccard Lag10
scatter3 = ax1.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag10'], s=df_1['Current_sp'], c=df_1['Current_sp'], cmap=cmap1, norm=norm1, alpha=0.7, marker='^', label='Jaccard Lag10')

scatter4 = ax1.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag50'], s=df_1['Current_sp'], c=df_1['Current_sp'], cmap=cmap1, norm=norm1, alpha=0.7, marker='*', label='Jaccard Lag50')

scatter5 = ax1.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag100'], s=df_1['Current_sp'], c=df_1['Current_sp'], cmap=cmap1, norm=norm1, alpha=0.7, marker='D', label='Jaccard Lag100')

scatter6 = ax1.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag200'], s=df_1['Current_sp'], c=df_1['Current_sp'], cmap=cmap1, norm=norm1, alpha=0.7, marker='x', label='Jaccard Lag200')

ax1.set_xlabel(r'Openness, Re($\lambda_m$)', fontsize=18)
ax1.set_ylabel('Jaccard Similarity', fontsize=18)
ax1.tick_params(axis='both', labelsize=18)
ax1.set_title("a", fontsize=20,loc="left",fontweight='bold')
cbar1 = fig.colorbar(scatter1, ax=ax1, label='Species richness')
cbar1.ax.yaxis.label.set_fontsize(18)
cbar1.ax.tick_params(axis='x', labelsize=20)
ax1.legend()

# Second subplot
ax2 = axes[1]
norm2 = plt.Normalize(df_1['Current_sp'].min(), df_1['Current_sp'].max())
cmap2 = cm.viridis

# Scatter plot for Prod_I_R
scatter2 = ax2.scatter(df_1['Eigen_mean'], df_1["Prod_I_R"], s=df_1['Current_sp'], c=df_1['Current_sp'], cmap=cmap2, norm=norm2, alpha=0.9)
ax2.set_xlabel(r'Openness, Re($\lambda_m$)', fontsize=18)
ax2.set_ylabel(r'Transition rate, $\hat{r}\rho$', fontsize=18)
ax2.tick_params(axis='both', labelsize=18)
ax2.set_title("b", fontsize=20,loc="left",fontweight='bold')
cbar2 = fig.colorbar(scatter2, ax=ax2, label='Species richness')
cbar2.ax.yaxis.label.set_fontsize(18)
cbar2.ax.tick_params(axis='x', labelsize=20)

# Adjust layout
plt.tight_layout()

plt.savefig("FigS5.png")   # PNG file
# plt.savefig("graph.jpg") # JPG file
# Show the plot
plt.show()

# %%
from matplotlib import cm
import matplotlib.pyplot as plt

# Create a figure with two subplots
fig, axes = plt.subplots(2, 1, figsize=(16, 16))

# First subplot
ax1 = axes[0]
norm1 = plt.Normalize(df_1['Current_sp'].min(), df_1['Current_sp'].max())
cmap1 = cm.viridis

# Scatter plot for Jaccard Lag1
scatter1 = ax1.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag1'], s=df_1['Current_sp'], c=df_1['Current_sp'], cmap=cmap1, norm=norm1, alpha=0.7, marker='o', label='Jaccard Lag1')

# Scatter plot for Jaccard Lag5
#scatter2 = ax1.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag5'], s=df_2['Current_sp'], c=df_2['Current_sp'], cmap=cmap1, norm=norm1, alpha=0.7, marker='s', label='Jaccard Lag5')

# Scatter plot for Jaccard Lag10
#scatter3 = ax1.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag10'], s=df_2['Current_sp'], c=df_2['Current_sp'], cmap=cmap1, norm=norm1, alpha=0.7, marker='^', label='Jaccard Lag10')

ax1.set_xlabel(r'Openness, Re($\lambda_m$)', fontsize=18)
ax1.set_ylabel('Jaccard Similarity,$T$', fontsize=18)
ax1.tick_params(axis='both', labelsize=18)
ax1.set_title("a", fontsize=20,loc="left",fontweight='bold')
cbar1 = fig.colorbar(scatter1, ax=ax1, label='Species richness')
cbar1.ax.yaxis.label.set_fontsize(18)
cbar1.ax.tick_params(axis='x', labelsize=20)
#ax1.legend()

# Second subplot
ax2 = axes[1]
norm2 = plt.Normalize(df_1['Current_sp'].min(), df_1['Current_sp'].max())
cmap2 = cm.viridis

# Scatter plot for Prod_I_R
scatter2 = ax2.scatter(df_1['Eigen_mean'], df_1["Prod_I_R"], s=df_1['Current_sp'], c=df_1['Current_sp'], cmap=cmap2, norm=norm2, alpha=0.9)
ax2.set_xlabel(r'Openness, Re($\lambda_m$)', fontsize=18)
ax2.set_ylabel(r'Transition rate, $\hat{r}\rho$', fontsize=18)
ax2.tick_params(axis='both', labelsize=18)
ax2.set_title("b", fontsize=20,loc="left",fontweight='bold')
cbar2 = fig.colorbar(scatter2, ax=ax2, label='Species richness')
cbar2.ax.yaxis.label.set_fontsize(18)
cbar2.ax.tick_params(axis='x', labelsize=20)

# Adjust layout
plt.tight_layout()

plt.savefig("Fig5.png")   # PNG file
# plt.savefig("graph.jpg") # JPG file
# Show the plot
plt.show()

# %%
from matplotlib import cm
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 8))
norm = plt.Normalize(df_1['Current_sp'].min(), df_1['Current_sp'].max())
cmap = cm.viridis  # Choose a colormap, e.g., viridis

# Create a scatter plot for Jaccard_lag1
scatter1 = plt.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag1'], s=df_1['Current_sp'], c=df_1['Current_sp'], cmap=cmap, norm=norm, alpha=0.7, marker='o', label='Jaccard Lag1')

# Create a scatter plot for Jaccard_lag5
scatter2 = plt.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag5'], s=df_1['Current_sp'], c=df_1['Current_sp'], cmap=cmap, norm=norm, alpha=0.7, marker='s', label='Jaccard Lag5')

# Create a scatter plot for Jaccard_lag10
scatter3 = plt.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag10'], s=df_1['Current_sp'], c=df_1['Current_sp'], cmap=cmap, norm=norm, alpha=0.7, marker='^', label='Jaccard Lag10')

# Add labels and title
plt.xlabel(r'Openness,mean(Re($\lambda_m$))',fontsize=18)
plt.ylabel('Jaccard Similarity',fontsize=18)

# Set font size for ticks
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

# Create a colorbar
cbar = plt.colorbar(scatter1, label='Species richness')
cbar.ax.yaxis.label.set_fontsize(18)
cbar.ax.tick_params(axis='x', labelsize=20) 
# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
from matplotlib import cm
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 8))
norm = plt.Normalize(df_1['Current_sp'].min(), df_1['Current_sp'].max())
cmap = cm.viridis  # Choose a colormap, e.g., viridis

# Create a scatter plot for Jaccard_lag1
scatter1 = plt.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag1'], s=df_1['Current_sp'], c=df_1['Current_sp'], cmap=cmap, norm=norm, alpha=0.7, marker='o', label='Jaccard Lag1')

# Create a scatter plot for Jaccard_lag5
scatter2 = plt.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag5'], s=df_1['Current_sp'], c=df_1['Current_sp'], cmap=cmap, norm=norm, alpha=0.7, marker='s', label='Jaccard Lag5')

# Create a scatter plot for Jaccard_lag10
scatter3 = plt.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag10'], s=df_1['Current_sp'], c=df_1['Current_sp'], cmap=cmap, norm=norm, alpha=0.7, marker='^', label='Jaccard Lag10')

# Add labels and title
plt.xlabel(r'Openness, Re($\lambda_m$)',fontsize=18)

plt.ylabel(r'Jaccard Similarity, $T$',fontsize=18)

# Set font size for ticks
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

# Create a colorbar
cbar = plt.colorbar(scatter1, label='Species richness')
cbar.ax.yaxis.label.set_fontsize(18)
cbar.ax.tick_params(axis='x', labelsize=20) 
# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
df_1['Prod_I_R']=None
for index, row in df_1.iterrows():
    product= row['Introd']*row['Ri']
    df_1.at[index, 'Prod_I_R'] = product
# Create the figure with adjusted figsize
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(16, 8), sharex=True, sharey='none')

# Plotting the column means
axs[0].scatter(df_1['Eigen_mean'],df_1['Jaccard_lag1'],ls=":", color = 'black',marker="o",alpha=1)
axs[0].scatter(df_1['Eigen_mean'],df_1['Jaccard_lag5'],ls=":", color = 'green',marker="o",alpha=1)
axs[0].scatter(df_1['Eigen_mean'],df_1['Jaccard_lag10'],ls=":", color = 'red',marker="o",alpha=1)
axs[0].scatter(df_1['Eigen_mean'],df_1['Jaccard_lag50'],ls=":", color = 'blue',marker="o",alpha=1)
axs[0].scatter(df_1['Eigen_mean'],df_1['Jaccard_lag100'],ls=":", color = 'brown',marker="o",alpha=1)
axs[0].set_ylabel(r"Jaccard Similarity, $T$", fontsize= 20)
axs[0].set_xlabel(r"Openness, mean(max(Re ($\lambda$)))", fontsize =20)
# Increase the font size of the tick labels
axs[0].tick_params(axis='both', labelsize=18)
# Add subplot label
#axs[0].text(25, 1,"a", fontsize=18, va='top')
# Bolden the tick labels
axs[0].xaxis.set_tick_params(which='both', width=1)
axs[0].yaxis.set_tick_params(which='both', width=1)
# Setting x-axis limits for scatter plots
#axs[0].set_xlim(0.95, 1)
axs[1].scatter(df_1['Eigen_mean'],df_1["Prod_I_R"],marker='o', color='black',ls="--")
axs[1].set_ylabel(r" Transition rate, $\hat{r}\rho$", fontsize= 20)
axs[1].set_xlabel(r"Openness, mean(max(Re ($\lambda$)))", fontsize =20)
# Increase the font size of the tick labels
axs[1].tick_params(axis='both', labelsize=18)
#axs[1].text(25, 1.54,"b", fontsize=18, va='top')
# Bolden the tick labels
axs[1].xaxis.set_tick_params(which='both', width=1)
axs[1].yaxis.set_tick_params(which='both', width=1)
# Set titles for subplots
axs[0].set_title("a", fontsize=20,loc="left",fontweight='bold')
axs[1].set_title("b", fontsize=20,loc="left",fontweight='bold')
plt.show()
#plt.xlabel('Lags')
#plt.ylabel('

# %%
from matplotlib import cm
plt.figure(figsize=(16, 8))
norm = plt.Normalize(df_1['Current_sp'].min(), df_1['Current_sp'].max())
cmap = cm.viridis  # Choose a colormap, e.g., viridis

# Create a scatter plot
scatter = plt.scatter(df_1['Eigen_mean'], df_1["Prod_I_R"], s=df_1['Current_sp'], c=df_1['Current_sp'], cmap=cmap, norm=norm, alpha=0.9)

# Add labels and title
plt.xlabel(r'mean(max(Re($\lambda$)))',fontsize=18)
plt.ylabel(r" Transition rate, $\hat{r}\rho$",fontsize=18)
#plt.title('Scatter Plot with Size-Based Colors')
# Set font size for ticks
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
# Create a colorbar
cbar = plt.colorbar(scatter, label='Species richness')
cbar.ax.yaxis.label.set_fontsize(18)
cbar.ax.tick_params(axis='x', labelsize=20) 
# Show the plot
plt.show()

# %%
df_1['Prod_I_R'] = None
for index, row in df_1.iterrows():
    product = row['Introd'] * row['Ri']
    df_1.at[index, 'Prod_I_R'] = product

# Create the figure with adjusted figsize
fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(16, 8), sharex=True, sharey='none')

# Plotting the column means
axs.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag1'], ls=":", color='black', marker="o", alpha=1, label='Lag1')
axs.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag5'], ls=":", color='green', marker="o", alpha=1, label='Lag5')
axs.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag10'], ls=":", color='red', marker="o", alpha=1, label='Lag10')
axs.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag50'], ls=":", color='blue', marker="o", alpha=1, label='Lag50')
axs.scatter(df_1['Eigen_mean'], df_1['Jaccard_lag100'], ls=":", color='brown', marker="o", alpha=1, label='Lag100')

axs.set_ylabel(r"Jaccard Similarity, $T$", fontsize=20)
axs.set_xlabel(r"Openness, mean(max(Re ($\lambda$)))", fontsize=20)

# Increase the font size of the tick labels
axs.tick_params(axis='both', labelsize=18)

# Add legend
axs.legend()

# Bolden the tick labels
axs.xaxis.set_tick_params(which='both', width=1)
axs.yaxis.set_tick_params(which='both', width=1)

plt.show()

# %% [markdown]
# ## supplementary graphs

# %%
df_Jvar = pd.read_excel('data_J_values_richness1.xlsx')

# %%
df_Jvar.columns
# Out:
# Index(['J_1000 ', 'J_3000  ', 'J_5000', 'J_7000 ', 'J_9000 ', 'J_11000',
#        'J_13000', 'J_15000', 'J_17000', 'J_19000'],
#       dtype='object')

# %%
J= [1000, 3000, 5000, 7000, 9000, 11000, 13000, 15000, 17000, 19000]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame df with columns 'J', 'Column1', 'Column2', ..., 'Column10'
# If not, replace these column names with your actual column names.

# Create a single plot for all 10 columns
plt.figure(figsize=(16, 8))  # Adjust the figure size as needed

# Iterate through columns and plot them
for col in df_Jvar.columns[1:]:
    plt.scatter(df_Jvar.index, df_Jvar[col], label=col)

# Add labels and legend
plt.xlabel('J Values',fontsize=18)
plt.ylabel('species Richness,S',fontsize=18)
plt.legend()
#plt.title('Community Size vs Species Richness')

# Set x-axis ticks as corresponding J values
#plt.xticks(df_Jvar.index, J)

# Show the plot
#plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame df with columns 'J', 'Column1', 'Column2', ..., 'Column10'
# If not, replace these column names with your actual column names.

# Create a single plot for all 10 columns
plt.figure(figsize=(16, 8))  # Adjust the figure size as needed

# Iterate through columns and plot them
for col in df_Jvar.columns[1:]:
    plt.plot(df_Jvar.index, df_Jvar[col], label=col)

# Add labels and legend
plt.xlabel('J Values',fontsize=18)
plt.ylabel('species Richness,S',fontsize=18)
plt.legend()
plt.title('Community Size vs Species Richness')

# Set x-axis ticks as corresponding J values
#plt.xticks(df_Jvar.index, J)

# Show the plot
#plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Assuming you have a DataFrame df with columns 'Column1', 'Column2', ..., 'Column10'
# If not, replace these column names with your actual column names.

# Create the list J
J = [1000, 3000, 5000, 7000, 9000, 11000, 13000, 15000, 17000, 19000]

# Calculate the mean of the DataFrame columns
column_means = df_Jvar.mean(axis=0)

# Create a single plot for all 10 columns
plt.figure(figsize=(16, 8))  # Adjust the figure size as needed

# Iterate through columns and plot them
for i, col in enumerate(df_Jvar.columns[0:], start=1):
    plt.scatter([i] * len(df_Jvar), df_Jvar[col], label=col)

# Add labels and legend
plt.xlabel('Community size, J',fontsize=18)
plt.ylabel('Species richness',fontsize=18)
#plt.legend()
#plt.title('Community Size vs Species Richness')
#J =[1000,3000,5000,7000,9000,11000,13000,15000,17000,19000]
# Set x-axis ticks as the column names
plt.xticks(range(1, len(df_Jvar.columns[0:]) + 1), J[0:], rotation=0)  # Rotate x-axis labels for readability

# Show the plot
#plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Assuming you have a DataFrame df with columns 'Column1', 'Column2', ..., 'Column10'
# If not, replace these column names with your actual column names.

# Create the list J
J = [1000, 3000, 5000, 7000, 9000, 11000, 13000, 15000, 17000, 19000]

# Calculate the mean of the DataFrame columns
column_means = df_Jvar.mean(axis=0)

X = pd.DataFrame({'J': J})
y = column_means
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)
r_squared = r2_score(y, y_pred)
# Create a single plot for all 10 columns
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed

# Iterate through columns and plot them
for i, col in enumerate(df_Jvar.columns[0:], start=1):
    plt.scatter([i] * len(df_Jvar), df_Jvar[col], label=col)

# Add labels and legend
plt.xlabel('Community size, J')
plt.ylabel('Species richness')
#plt.legend()
plt.title('Scatter Plot of All Columns')
plt.annotate(f'R^2 = {r_squared:.2f}',(J[0], df_Jvar[col].max()))
# Set x-axis ticks as the column names
plt.xticks(range(1, len(df_Jvar.columns[0:]) + 1), J[0:], rotation=0)  # Rotate x-axis labels for readability

# Show the plot
#plt.grid(True)
plt.show()

# %%
r_squared
# Out:
# 0.9600503093244428

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your dataframe is named 'df' and contains the five columns of interest
columns_of_interest = ['Jaccard_lag1', 'Jaccard_lag5', 'Jaccard_lag10', 'Jaccard_lag50', 'Jaccard_lag100','Jaccard_lag200']  # Replace with actual column names

# Select the five columns from the dataframe
selected_columns = df_1[columns_of_interest]

# Calculate the mean of each column
column_means = selected_columns.mean()

# Assuming your dataframe is named 'df' and contains the five columns of interest
columns_of_interest1 = ['DeltaRAO1', 'DeltaRAO5', 'DeltaRAO10', 'DeltaRAO50', 'DeltaRAO100','DeltaRAO200']  # Replace with actual column names

# Select the five columns from the dataframe
selected_columns1 = df_1[columns_of_interest1]

# Calculate the mean of each column
column_means1 = selected_columns1.mean()

c=[1,5,10,50,100,200]

# Create the figure with adjusted figsize
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(16, 8), sharex=True, sharey='none')

# Plotting the column means
axs[0].plot(c, column_means, color='red',ls=":", marker="*",alpha=1)
axs[0].set_ylabel("Mean Jaccard Simmilarity", fontsize= 20)
axs[0].set_xlabel(r"Time lag, $\tau$", fontsize =20)
# Increase the font size of the tick labels
axs[0].tick_params(axis='both', labelsize=18)
# Add subplot label
#/axs[0].text(100, 1.08,"a", fontsize=18, va='top')

# Bolden the tick labels
axs[0].xaxis.set_tick_params(which='both', width=1)
axs[0].yaxis.set_tick_params(which='both', width=1)
axs[1].plot(c, column_means1,color='green',marker='o',ls="--")
axs[1].set_ylabel("Mean Functional Turnover", fontsize= 20)
axs[1].set_xlabel(r"Time lag,$\tau$", fontsize =20)
# Increase the font size of the tick labels
axs[1].tick_params(axis='both', labelsize=18)
#axs[1].text(100, 1.89,"b", fontsize=18, va='top')
# Bolden the tick labels
axs[1].xaxis.set_tick_params(which='both', width=1)
axs[1].yaxis.set_tick_params(which='both', width=1)
#plt.xlabel('Lags')
#plt.ylabel('Mean')
plt.show()

# %%
df_1['Prod_I_R']=None
for index, row in df_1.iterrows():
    product= row['Introd']*row['Ri']
    df_1.at[index, 'Prod_I_R'] = product
# Create the figure with adjusted figsize
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(16, 8), sharex=True, sharey='none')

# Plotting the column means
axs[0].scatter(df_1['Eigen_mean'],df_1['Jaccard_lag1'],ls=":", color = 'black',marker="o",alpha=1)
axs[0].scatter(df_1['Eigen_mean'],df_1['Jaccard_lag5'],ls=":", color = 'green',marker="o",alpha=1)
axs[0].scatter(df_1['Eigen_mean'],df_1['Jaccard_lag10'],ls=":", color = 'red',marker="o",alpha=1)
axs[0].scatter(df_1['Eigen_mean'],df_1['Jaccard_lag50'],ls=":", color = 'blue',marker="o",alpha=1)
axs[0].scatter(df_1['Eigen_mean'],df_1['Jaccard_lag100'],ls=":", color = 'brown',marker="o",alpha=1)
axs[0].set_ylabel(r"Jaccard Similarity, $T$", fontsize= 20)
axs[0].set_xlabel(r"Openness, mean(max(Re ($\lambda$)))", fontsize =20)
# Increase the font size of the tick labels
axs[0].tick_params(axis='both', labelsize=18)
# Add subplot label
#axs[0].text(25, 1,"a", fontsize=18, va='top')
# Bolden the tick labels
axs[0].xaxis.set_tick_params(which='both', width=1)
axs[0].yaxis.set_tick_params(which='both', width=1)
# Setting x-axis limits for scatter plots
#axs[0].set_xlim(0.95, 1)
axs[1].scatter(df_1['Eigen_mean'],df_1["Prod_I_R"],marker='o', color='black',ls="--")
axs[1].set_ylabel(r" Transition rate, $\hat{r}\rho$", fontsize= 20)
axs[1].set_xlabel(r"Openness, mean(max(Re ($\lambda$)))", fontsize =20)
# Increase the font size of the tick labels
axs[1].tick_params(axis='both', labelsize=18)
#axs[1].text(25, 1.54,"b", fontsize=18, va='top')
# Bolden the tick labels
axs[1].xaxis.set_tick_params(which='both', width=1)
axs[1].yaxis.set_tick_params(which='both', width=1)
# Set titles for subplots
axs[0].set_title("a", fontsize=20,loc="left",fontweight='bold')
axs[1].set_title("b", fontsize=20,loc="left",fontweight='bold')
plt.show()
#plt.xlabel('Lags')
#plt.ylabel('

# %%
# Create the figure with adjusted figsize
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(16, 8), sharex=True, sharey='none')

# Plotting the column means
axs[0].scatter(df_1['Current_sp'],df_1['Jaccard_lag1'],ls=":", color = 'black',marker="o",alpha=1)
axs[0].set_ylabel(r"Jaccard Similarity, $\tau$", fontsize= 20)
axs[0].set_xlabel(r"Species richness, $S$", fontsize =20)
# Increase the font size of the tick labels
axs[0].tick_params(axis='both', labelsize=18)
# Add subplot label
#axs[0].text(25, 1,"a", fontsize=18, va='top')
# Bolden the tick labels
axs[0].xaxis.set_tick_params(which='both', width=1)
axs[0].yaxis.set_tick_params(which='both', width=1)
# Setting x-axis limits for scatter plots
#axs[0].set_xlim(0.95, 1)
axs[1].scatter(df_1['Current_sp'],df_1["DeltaRAO1"],marker='o', color='black',ls="--")
axs[1].set_ylabel(r" Functional Turnover, $Q$", fontsize= 20)
axs[1].set_xlabel(r"Species richness, $S$", fontsize =20)
# Increase the font size of the tick labels
axs[1].tick_params(axis='both', labelsize=18)
#axs[1].text(25, 1.54,"b", fontsize=18, va='top')
# Bolden the tick labels
axs[1].xaxis.set_tick_params(which='both', width=1)
axs[1].yaxis.set_tick_params(which='both', width=1)
# Set titles for subplots
axs[0].set_title("a", fontsize=20,loc="left",fontweight='bold')
axs[1].set_title("b", fontsize=20,loc="left",fontweight='bold')
plt.show()
#plt.xlabel('Lags')
#plt.ylabel('

# %%
import matplotlib.pyplot as plt

# Create the figure with adjusted figsize
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(16, 8), sharex=True, sharey='none')

# Plotting the column means
scatter1 = axs[0].scatter(df_1['Eigen_mean'], df_1['Jaccard_lag1'], ls=":", marker="o", alpha=1, label='Jaccard Lag 1')
scatter2 = axs[0].scatter(df_1['Eigen_mean'], df_1['Jaccard_lag5'], ls=":", marker="o", alpha=1, label='Jaccard Lag 5')
scatter2 = axs[0].scatter(df_1['Eigen_mean'], df_1['Jaccard_lag10'], ls=":", marker="o", alpha=1, label='Jaccard Lag 10')
scatter2 = axs[0].scatter(df_1['Eigen_mean'], df_1['Jaccard_lag50'], ls=":", marker="o", alpha=1, label='Jaccard Lag 50')
scatter2 = axs[0].scatter(df_1['Eigen_mean'], df_1['Jaccard_lag100'], ls=":", marker="o", alpha=1, label='Jaccard Lag 100')
scatter2 = axs[0].scatter(df_1['Eigen_mean'], df_1['Jaccard_lag200'], ls=":", marker="o", alpha=1, label='Jaccard Lag 200')


axs[0].set_ylabel("Jaccard Similarity", fontsize=20)
axs[0].set_xlabel("Mean Eigenvalues", fontsize=20)
axs[0].tick_params(axis='both', labelsize=18)
#axs[0].text(25, 1, "(a)", fontsize=18, va='top')
axs[0].xaxis.set_tick_params(which='both', width=1)
axs[0].yaxis.set_tick_params(which='both', width=1)
axs[0].legend(loc='best')  # Add legend to subplot 0

scatter3 = axs[1].scatter(df_1['Eigen_mean'], df_1["Prod_I_R"], marker='o', ls="--", label='Transition rate')

axs[1].set_ylabel("Transition rate", fontsize=20)
axs[1].set_xlabel("Mean Eigenvalues", fontsize=20)
axs[1].tick_params(axis='both', labelsize=18)
#axs[1].text(25, 1.54, "(b)", fontsize=18, va='top')
axs[1].xaxis.set_tick_params(which='both', width=1)
axs[1].yaxis.set_tick_params(which='both', width=1)
axs[1].legend(loc='best')  # Add legend to subplot 1

# Set titles for subplots
axs[0].set_title("a", fontsize=20,loc="left")
axs[1].set_title("b", fontsize=20,loc="left")

plt.show()

# %%
import matplotlib.pyplot as plt

# Create the figure with adjusted figsize
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(16, 8), sharex=True, sharey='none')

# Plotting the column means
#scatter1 = axs[0].scatter(df_1['Eigen_mean'], df_1['Jaccard_lag1'], ls=":", marker="o", alpha=1, label='Jaccard Lag 1')
scatter2 = axs[0].scatter(df_1['Eigen_mean'], df_1['Jaccard_lag5'], ls=":", marker="o", alpha=1, label='Jaccard Lag 5')
scatter3 = axs[0].scatter(df_1['Eigen_mean'], df_1['Jaccard_lag10'], ls=":", marker="o", alpha=1, label='Jaccard Lag 10')
scatter4 = axs[0].scatter(df_1['Eigen_mean'], df_1['Jaccard_lag50'], ls=":", marker="o", alpha=1, label='Jaccard Lag 50')
scatter5 = axs[0].scatter(df_1['Eigen_mean'], df_1['Jaccard_lag100'], ls=":", marker="o", alpha=1, label='Jaccard Lag 100')
scatter6 = axs[0].scatter(df_1['Eigen_mean'], df_1['Jaccard_lag200'], ls=":", marker="o", alpha=1, label='Jaccard Lag 200')


axs[0].set_ylabel(r" Jaccard Similarity,$T$", fontsize=20)
axs[0].set_xlabel(r'Openness, Re($\lambda_m$)', fontsize=20)
axs[0].tick_params(axis='both', labelsize=18)
#axs[0].text(25, 1, "(a)", fontsize=18, va='top')
axs[0].xaxis.set_tick_params(which='both', width=1)
axs[0].yaxis.set_tick_params(which='both', width=1)
axs[0].legend(loc='best')  # Add legend to subplot 0

# Plotting the column means
#scatter1 = axs[1].scatter(-1*df_1['Eigen_mean'], df_1['DeltaRAO1'], ls=":", marker="o", alpha=1, label='DeltaRAO lag 1')
scatter2 = axs[1].scatter(df_1['Eigen_mean'], df_1['DeltaRAO5'], ls=":", marker="o", alpha=1, label='DeltaRAO lag 5')
scatter3 = axs[1].scatter(df_1['Eigen_mean'], df_1['DeltaRAO10'], ls=":", marker="o", alpha=1, label='DeltaRAO Lag 10')
scatter4 = axs[1].scatter(df_1['Eigen_mean'], df_1['DeltaRAO50'], ls=":", marker="o", alpha=1, label='DeltaRAO Lag 50')
scatter5= axs[1].scatter(df_1['Eigen_mean'], df_1['DeltaRAO100'], ls=":", marker="o", alpha=1, label='DeltaRAO Lag 100')
scatter6 = axs[1].scatter(df_1['Eigen_mean'], df_1['DeltaRAO200'], ls=":", marker="o", alpha=1, label='DeltaRAO Lag 200')

axs[1].set_ylabel(r"Functional Turnover, $\Delta Q$", fontsize=20)
axs[1].set_xlabel(r'Openness, Re($\lambda_m$)', fontsize=20)
axs[1].tick_params(axis='both', labelsize=18)
#axs[1].text(25, 1.54, "(b)", fontsize=18, va='top')
axs[1].xaxis.set_tick_params(which='both', width=1)
axs[1].yaxis.set_tick_params(which='both', width=1)
axs[1].legend(loc='best')  # Add legend to subplot 1
axs[0].set_title("a", fontsize=20,loc="left",fontweight='bold')
axs[1].set_title("b", fontsize=20,loc="left",fontweight='bold')
# Set titles for subplots
plt.savefig("FigS4.png")   # PNG file
# plt.savefig("graph.jpg") # JPG file
plt.show()

# %%
plt.scatter(df_1['Eigen_mean'],df_1['RAO_mean'],ls=":", marker="o", alpha=1, label='RAO diversity')
plt.show()

# %%
plt.figure(figsize=(16, 8))
plt.plot(df_1['RAO_mean'],color='black')
#plt.plot(b[800:], label = 'Exinctions')
plt.xlabel("Communities", fontsize=20)
plt.ylabel("Functional diversity, $Q$",fontsize=20)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.legend()
plt.show()

# %%
df_3
# Out:
#       Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0     Richness_0  Richness_1  Richness_2  Richness_3  Richness_4  Richness_5
# 1            300         300         300         300         300         300
# 2            300         300         300         300         300         300
# 3              0           0           0           0           0           0
# 4              0           0           0           0           0           0
# ...          ...         ...         ...         ...         ...         ...
# 1796         401         250         357         216         372         239
# 1797         404         246         360         216         370         238
# 1798         403         245         355         216         371         238
# 1799         403         245         359         216         374         237
# 1800         404         245         350         214         376         236
#
#       Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ... Unnamed: 31  \
# 0     Richness_6  Richness_7         NaN         NaN  ...        59.0
# 1            300         300         NaN         NaN  ...        26.0
# 2            300         300         NaN         NaN  ...        55.0
# 3              0           0         NaN         NaN  ...        21.0
# 4              0           0         NaN         NaN  ...        51.0
# ...          ...         ...         ...         ...  ...         ...
# 1796         355         221         NaN         NaN  ...         NaN
# 1797         353         222         NaN         NaN  ...         NaN
# 1798         356         219         NaN         NaN  ...         NaN
# 1799         359         216         NaN         NaN  ...         NaN
# 1800         361         221         NaN         NaN  ...         NaN
#
#      Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36 Unnamed: 37  \
# 0           65.0        71.0        76.0        82.0        88.0        89.0
# 1           27.0        32.0        34.0        37.0        38.0        39.0
# 2           59.0        61.0        65.0        72.0        78.0        85.0
# 3           21.0        24.0        26.0        28.0        28.0        29.0
# 4           54.0        60.0        64.0        69.0        73.0        79.0
# ...          ...         ...         ...         ...         ...         ...
# 1796         NaN         NaN         NaN         NaN         NaN         NaN
# 1797         NaN         NaN         NaN         NaN         NaN         NaN
# 1798         NaN         NaN         NaN         NaN         NaN         NaN
# 1799         NaN         NaN         NaN         NaN         NaN         NaN
# 1800         NaN         NaN         NaN         NaN         NaN         NaN
#
#      Unnamed: 38  Unnamed: 39 Unnamed: 40
# 0           92.0         97.0       103.0
# 1           40.0         42.0        43.0
# 2           89.0         93.0        97.0
# 3           30.0         30.0        31.0
# 4           88.0         89.0        97.0
# ...          ...          ...         ...
# 1796         NaN          NaN         NaN
# 1797         NaN          NaN         NaN
# 1798         NaN          NaN         NaN
# 1799         NaN          NaN         NaN
# 1800         NaN          NaN         NaN
#
# [1801 rows x 41 columns]

# %%
sliced_df = df_3.iloc[1:, :8]

# %%
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df'

# Get the number of columns in the DataFrame
num_columns = len(sliced_df.columns)

# Calculate the number of rows and columns for the subplots grid
num_rows = int(num_columns ** 0.5)  # You can adjust this as needed
num_cols = (num_columns + num_rows - 1) // num_rows

# Create subplots with specified alignment
fig, axs = plt.subplots(num_rows, num_cols, figsize=(12, 8), sharex=True, sharey=True)

# Set titles for each subplot
titles = ['a','b','c','d','e','f','g','h']

# Loop through columns and plot each one in a separate subplot with titles
for i, column in enumerate(sliced_df.columns):
    row = i // num_cols
    col = i % num_cols
    axs[row, col].plot(sliced_df[column])
    axs[row, col].set_title(titles[i], fontsize=20,loc='left',fontweight='bold')
    if i%2==0 and col==0:
        # Add labels and legend
        axs[row, col].set_ylabel('Species richness', fontsize=20, color='black')
    if row==1 and col>=0:
        # Add labels and legend
        axs[row, col].set_xlabel('Time', fontsize=20, color='black')

# Adjust layout and show the plot
#axs[0].set_ylabel('Species richness',fontsize=20)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming you have a DataFrame called fina_df

# Create a figure and axes
fig, ax = plt.subplots(figsize=(16, 8))

# Plot the data from the column
ax.plot(df_2['Richness_2'])

# Define the positions of vertical lines
initial_line = 200
transient_line = 800
stationary_line = 1800

# Add vertical lines at the specified positions
ax.axvline(x=initial_line, color='red', linestyle='--')
ax.axvline(x=transient_line, color='blue', linestyle='--')
#ax.axvline(x=stationary_line, color='green', linestyle='--')

# Set x-axis ticks
ax.set_xticks(range(0, 1800 + 1, 300))

# Set labels for x-axis and y-axis
ax.set_xlabel('Time, $t$', fontsize=20)
ax.set_ylabel('Species richness', fontsize=20)

# Increase the font size of the tick labels
ax.tick_params(axis='both', labelsize=18)

# Bolden the tick labels
ax.xaxis.set_tick_params(which='both', width=1)
ax.yaxis.set_tick_params(which='both', width=1)

# Add text labels for the ranges
ax.text(50, max(df_2['Richness_2'])+18, 'Initial', rotation=0, va='top', ha='center', fontsize=18,fontweight='bold')
ax.text((initial_line + transient_line) / 2, max(df_2['Richness_2'])+18, 'Transient', rotation=0, va='top', ha='center', fontsize=18,fontweight='bold')
ax.text((transient_line + stationary_line) / 2,max(df_2['Richness_2'])+18, 'Stationary', rotation=0, va='top', ha='center', fontsize=18,fontweight='bold')

# Save the plot as a PNG image
plt.savefig('local_com.png', dpi=900)

# %%
import matplotlib.pyplot as plt

# Create the figure with adjusted figsize
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(16, 8), sharex=True, sharey='none')

# Plotting the column means
scatter1 = axs[0].scatter(df_1['Eigen_mean'], df_1['DeltaRAO1'], ls=":", marker="o", alpha=1, label='Jaccard Lag 1')
scatter2 = axs[0].scatter(df_1['Eigen_mean'], df_1['DeltaRAO5'], ls=":", marker="o", alpha=1, label='Jaccard Lag 5')
scatter2 = axs[0].scatter(df_1['Eigen_mean'], df_1['DeltaRAO10'], ls=":", marker="o", alpha=1, label='Jaccard Lag 10')
scatter2 = axs[0].scatter(df_1['Eigen_mean'], df_1['DeltaRAO50'], ls=":", marker="o", alpha=1, label='Jaccard Lag 50')
scatter2 = axs[0].scatter(df_1['Eigen_mean'], df_1['DeltaRAO100'], ls=":", marker="o", alpha=1, label='Jaccard Lag 100')
scatter2 = axs[0].scatter(df_1['Eigen_mean'], df_1['DeltaRAO200'], ls=":", marker="o", alpha=1, label='Jaccard Lag 200')


axs[0].set_ylabel("Mean Jaccard Similarity", fontsize=20)
axs[0].set_xlabel("Mean Eigenvalues", fontsize=20)
axs[0].tick_params(axis='both', labelsize=18)
#axs[0].text(25, 1, "(a)", fontsize=18, va='top')
axs[0].xaxis.set_tick_params(which='both', width=1)
axs[0].yaxis.set_tick_params(which='both', width=1)
axs[0].legend(loc='best')  # Add legend to subplot 0

scatter3 = axs[1].scatter(df_1['Eigen_mean'], df_1["Prod_I_R"], marker='o', ls="--", label='Transition rate')

axs[1].set_ylabel("Transition rate", fontsize=20)
axs[1].set_xlabel("Mean Eigenvalues", fontsize=20)
axs[1].tick_params(axis='both', labelsize=18)
#axs[1].text(25, 1.54, "(b)", fontsize=18, va='top')
axs[1].xaxis.set_tick_params(which='both', width=1)
axs[1].yaxis.set_tick_params(which='both', width=1)
axs[1].legend(loc='best')  # Add legend to subplot 1

# Set titles for subplots
axs[0].set_title("a", fontsize=20)
axs[1].set_title("b", fontsize=20)

plt.show()
